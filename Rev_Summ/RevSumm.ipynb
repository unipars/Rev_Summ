# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/unipars/Rev_Summ.git

# %%
# !git config --global user.name "unipars"
# !git config --global user.email "f.farrokhi@gmail.com"

# %%
# !pip install --quiet openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 19.0 MB/s eta 0:00:00

# %%
import openai
import os

# %%
os.chdir('/content/drive/MyDrive/Colab_Notebooks/Git/FarshidFarrokhi_ReviewSummarizer/Rev_Summ')

# %%
import utils as ut

# %%
review = ut.get_review()
# Out:
# Enter desired review: Handy location on way up to Inverness, across road from picturesque Loch. Nice reception and bar area (although bar was VERY brightly lit like an airport waiting lounge, could be lovely with lights dimmed, decor very tasteful). Friendly lady on reception. Long way to room, bit like a maze and we noticed on the way that the carpets on all the stairs and corridors needed a darn good vaccuuming. Room quite pleasant but window frame had quite a lot of black mould around the inside and some wallpaper peeling off in corner with more black mould underneath. They've skimped so much on the fabric of the (new) curtains that they didn't cover the window when closed, something I've never seen before in a hotel! We found it funny...very Fawlty Towers. Carpet HAD been vaccuumed and bathroom clean but more black mould in grout on bath tiles. Room quiet, beds very comfy (and clean). Didn't try restaurant but cooked breakfast was good. We also had a giggle in the bar with the fr
# ...

# %%
ut.extract_opinion(review)
# Out:
# The review has 1271 words.
# Cleanliness:
# - Carpets on stairs and corridors needed vacuuming.
# - Window frame had black mold and wallpaper peeling off in the room.
# - Curtains were not able to cover the window when closed.
# - Black mold in grout on bath tiles.
#
# Staff:
# - Friendly lady on reception.
# - Friendly locals in the bar giving advice on the area.
# - Cabaret singer had a great voice, but was very cheesy.
# - Scottish dancers were an unexpected treat.
#
# Food & Restaurant:
# - Cooked breakfast was good.
#
# Dear [Customer Name],
#
# Thank you for taking the time to share your thoughts about your recent stay at our hotel. We sincerely appreciate your feedback, as it helps us to improve the quality of our services.
#
# We are thrilled to hear that our staff was friendly and welcoming during your stay. It is also great to know that you enjoyed your breakfast and had a fun time in the bar with the locals and the entertainment.
#
# ...
