# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
token = "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"
username = "unipars"
repo = "Rev_Summ"

path = "/content/drive/MyDrive/Colab_Notebooks/Git/FarshidFarrokhi_ReviewSummarizer/Rev_Summ"

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'Rev_Summ'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), 1.25 KiB | 1.25 MiB/s, done.

# %%
# !git config --global user.name "F.Farrokhi"
# !git config --global user.email "f.farrokhi@gmail.com"

# %%
# %cd {repo}
# Out:
# /content/Rev_Summ

# %%
# !cp -r /content/Rev_Summ {path}

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
